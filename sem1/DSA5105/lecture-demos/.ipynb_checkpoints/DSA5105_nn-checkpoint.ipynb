# %% [markdown]
# # Preface
#
# In this notebook, we
#   * Investigate the effects of gradient descent and stochastic gradient descent on training NNs
#   * Apply CNNs for basic image recognition tasks
#
# This also serves to introduce the basics of the `keras` library with `tensorflow` backend.
#
# Install this library with
# ```
# $pip install tensorflow
# ```

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

# %%
sns.set_context('notebook', font_scale=1.25, rc={"lines.linewidth": 2.5})
sns.set_style("darkgrid")
np.random.seed(123)  # For reproducibility

# %% [markdown]
# # Fashion MNIST Dataset
#
# The [Fashion MNIST](https://github.com/zalandoresearch/fashion-mnist) dataset serves as one of the most basic benchmarks for image recognition. It is a dataset of Zalando's article images—consisting of a training set of 60,000 examples and a test set of 10,000 examples. Each example is a 28x28 grayscale image, associated with a label from 10 classes. Thus, it is almost exactly like the MNIST dataset for digit recognition, but generally harder.
#
# ![Fashion MNIST](https://markusthill.github.io/images/2017-10-12-zalandos-fashion-mnist-dataset/zalando10x10.jpeg)

# %% [markdown]
# We can load the fashion MNIST data directly using `keras` as follows. We will need some simple preprocessing.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# %%
x_train = x_train[:, :, :, np.newaxis] / 255.0  # Add channel dimension and normalize to [0, 1]
x_test = x_test[:, :, :, np.newaxis] / 255.0  # Add channel dimension and normalize to [0, 1]
y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)  # convert to one-hot
y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

# %% [markdown]
# We will also keep an array of labels in words for plotting purposes.

# %%
label_dict = {
    0: 'T-shirt/top',
    1: 'Trouser',
    2: 'Pullover',
    3: 'Dress',
    4: 'Coat',
    5: 'Sandal',
    6: 'Shirt',
    7: 'Sneaker',
    8: 'Bag',
    9: 'Ankle boot',
}
labels_train = np.asarray([label_dict[u.argmax(0)] for u in y_train])
labels_test = np.asarray([label_dict[u.argmax(0)] for u in y_test])

# %% [markdown]
# Let us look at some example images

# %%
def plot_images(x, labels=None, nrow=2, ncol=4, im_type='image'):
    if im_type == 'filter':
        x = x.transpose(3, 0, 1, 2)  # Transpose to image type
    fig, ax = plt.subplots(nrow, ncol, figsize=(5*ncol, 4*nrow))
    num_samples = x.shape[0]
    num_channels = x.shape[-1]
    for a in ax.ravel():
        j = np.random.choice(num_samples)
        k = np.random.choice(num_channels)
        sns.heatmap(x[j, :, :, k], ax=a, cbar=False, cmap='gray_r')
        if labels is not None:
            a.set_title(labels[j])
        a.set_xticks([])
        a.set_yticks([])

plot_images(x_train, labels=labels_train)

# %% [markdown]
# # Fully Connected Neural Networks for Image Classification
#
# Here we will introduce the simplest functionalities of `keras`. We will mostly use the [functional API](https://keras.io/getting-started/functional-api-guide/) since it is quite flexible and gets the job done for most basic use-cases. For more complex use-cases, one will often need to do [model-subclassing](https://keras.io/models/about-keras-models/).

# %%
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.models import Model

# %% [markdown]
# In a sense, the lowest level of abstraction in Keras is *layers*. We build a network consisting of layer objects. Model is a child of the Layer class that has additional functionalities.

# %%
x = Input(shape=(28, 28, 1))
x_flat = Flatten()(x)
x_1 = Dense(units=32, activation='relu')(x_flat)
x_2 = Dense(units=10, activation='softmax')(x_1)
shallow_nn = Model(inputs=x, outputs=x_2)

# %% [markdown]
# We can also print a summary of the network, which is useful. Alternatively, you can use `keras.utils.plot_model` to visualize, but this requires installing the [`graphviz`](https://graphviz.gitlab.io/about/) package. For simplicity, we will not do that here. If you are interested, feel free to explore!

# %%
shallow_nn.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 32)                25120
#
#  dense_1 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 25,450
# Trainable params: 25,450
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Next, we need to specify the loss functions and the optimizer we want to use. Finally, we want to monitor the *accuracy* metric. This can all be done in the `compile` method of `Model`.
#
# We will use the *cross-entropy loss* with the *SGD* optimizer. We will monitor the *accuracy*, in addition to the loss values. Do check out other choices as well and play around with them!
#   * [Other losses](https://www.tensorflow.org/api_docs/python/tf/keras/losses)
#   * [Other optimizers](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/)
#   * [Other metrics](https://www.tensorflow.org/api_docs/python/tf/keras/metrics/)

# %%
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.optimizers import SGD

# %%
shallow_nn.compile(
    loss=categorical_crossentropy,
    optimizer=SGD(0.01),
    metrics=['accuracy'],
)

# %%
initial_weights = shallow_nn.get_weights()  # We save initial weights for later use

# %% [markdown]
# We are now ready to train our model. Simply call the `train` method, while specifying suitable arguments.

# %%
shallow_nn.fit??

# %%
history = shallow_nn.fit(
    x=x_train,
    y=y_train,
    batch_size=128,
    epochs=10,
    validation_data=(x_test, y_test),
    verbose=2,
)
# Out:
# Epoch 1/10
# 469/469 - 1s - loss: 0.4253 - accuracy: 0.8529 - val_loss: 0.4576 - val_accuracy: 0.8404 - 507ms/epoch - 1ms/step
# Epoch 2/10
# 469/469 - 0s - loss: 0.4221 - accuracy: 0.8536 - val_loss: 0.4604 - val_accuracy: 0.8402 - 468ms/epoch - 998us/step
# Epoch 3/10
# 469/469 - 0s - loss: 0.4190 - accuracy: 0.8530 - val_loss: 0.4533 - val_accuracy: 0.8432 - 492ms/epoch - 1ms/step
# Epoch 4/10
# 469/469 - 0s - loss: 0.4164 - accuracy: 0.8556 - val_loss: 0.4528 - val_accuracy: 0.8406 - 472ms/epoch - 1ms/step
# Epoch 5/10
# 469/469 - 0s - loss: 0.4135 - accuracy: 0.8568 - val_loss: 0.4487 - val_accuracy: 0.8427 - 445ms/epoch - 950us/step
# Epoch 6/10
# 469/469 - 1s - loss: 0.4115 - accuracy: 0.8574 - val_loss: 0.4474 - val_accuracy: 0.8431 - 524ms/epoch - 1ms/step
# Epoch 7/10
# 469/469 - 0s - loss: 0.4090 - accuracy: 0.8580 - val_loss: 0.4448 - val_accuracy: 0.8444 - 464ms/epoch - 990us/step
# Epoch 8/10
# 469/469 - 0s - loss: 0.4067 - accuracy: 0.8591 - val_loss: 0.4420 - val_accuracy: 0.8434 - 455ms/epoch - 971us/step
# Epoch 9/10
# 469/469 - 1s - loss: 0.4044 - accuracy: 0.8596 - val_loss: 0.4438 - val_accuracy: 0.8431 - 529ms/epoch - 1ms/step
# Epoch 10/10
# 469/469 - 0s - loss: 0.4019 - accuracy: 0.8612 - val_loss: 0.4404 - val_accuracy: 0.8433 - 467ms/epoch - 996us/step

# %% [markdown]
# The history object can be converted into a dataframe for easy analysis and plotting

# %%
history_df = pd.DataFrame(history.history)
history_df['epoch'] = history.epoch
history_df.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy  epoch
# 0  0.425252  0.852883  0.457594        0.8404      0
# 1  0.422100  0.853600  0.460368        0.8402      1
# 2  0.418998  0.852983  0.453275        0.8432      2
# 3  0.416385  0.855633  0.452838        0.8406      3
# 4  0.413504  0.856817  0.448718        0.8427      4

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 4))

history_df.plot(x='epoch', y=['loss', 'val_loss'], ax=ax[0])
history_df.plot(x='epoch', y=['accuracy', 'val_accuracy'], ax=ax[1])
# Out:
# <AxesSubplot:xlabel='epoch'>

# %% [markdown]
# ## The Effect of Learning Rate on SGD
#
# Let us now investigate the effect of varying learning rate on SGD performance. We will write a simple wrapper to clean up the evaluation code.

# %%
class ParamEvaluator(object):
    def __init__(self,
                 model,
                 compile_default,
                 fit_default,
                 initial_weights=None):
        self.model = model
        self.compile_default = compile_default
        self.fit_default = fit_default
        self.initial_weights = initial_weights or model.get_weights()

    def reset_model(self):
        self.model.set_weights(self.initial_weights)

    def evaluate(self, **overrides):
        # reset model
        self.reset_model()
        
        # override and compile
        compile_overrides = {
            k: v
            for k, v in overrides.items() if k in self.compile_default.keys()
        }
        compile_updated = {**self.compile_default, **compile_overrides}
        self.model.compile(**compile_updated)

        # override and fit
        fit_overrides = {
            k: v
            for k, v in overrides.items() if k in self.fit_default.keys()
        }
        fit_updated = {**self.fit_default, **fit_overrides}
        history = self.model.fit(**fit_updated)
        history_df = pd.DataFrame(history.history)
        history_df['epoch'] = history.epoch
        return history_df

# %% [markdown]
# For fast evaluation for presentation purposes, we are going to reduce the size of the training set by 10 times. You are encouraged to try out the full version at home!

# %%
evaluator = ParamEvaluator(
    model=shallow_nn,
    initial_weights=initial_weights,
    compile_default={
        'loss': categorical_crossentropy,
        'optimizer': SGD(learning_rate=0.01),
        'metrics': ['accuracy'],
    },
    fit_default={
        'x': x_train[:6000],  # reduce training set
        'y': y_train[:6000],  # reduce training set
        'batch_size': 128,
        'epochs': 10,
        'validation_data': (x_test, y_test),
        'verbose': 0  # silences output    
    }
)

# %% [markdown]
# Let us now investigate the effect of varying learning rates

# %%
results_1 = evaluator.evaluate(optimizer=SGD(1.0))
results_05 = evaluator.evaluate(optimizer=SGD(0.5))
results_001 = evaluator.evaluate(optimizer=SGD(0.01))

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 4), sharey=True)

results_1.plot(x='epoch', y=['loss', 'val_loss'], ax=ax[0], title='Learning rate = 1.0')
results_05.plot(x='epoch', y=['loss', 'val_loss'], ax=ax[1], title='Learning rate = 0.5')
results_001.plot(x='epoch', y=['loss', 'val_loss'], ax=ax[2], title='Learning rate = 0.1')
# Out:
# <AxesSubplot:title={'center':'Learning rate = 0.1'}, xlabel='epoch'>

# %% [markdown]
# ## The Effect of Batch Size on SGD
#
# For fair comparison in terms of training/testing loss, if we increase the batch size we should increase the number of epochs in the same proportions. This ensures that the number of SGD runs is constant for each case.
#
# **Remark.** For GPU training, the wall-clock does not scale linearly in batch size! Try it out if you have access to a GPU.

# %%
results_16 = evaluator.evaluate(optimizer=SGD(0.05), batch_size=16, epochs=8)
results_32 = evaluator.evaluate(optimizer=SGD(0.05), batch_size=32, epochs=16)
results_128 = evaluator.evaluate(optimizer=SGD(0.05), batch_size=128, epochs=64)

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 4), sharey=True)

results_16.plot(x='epoch', y=['loss', 'val_loss'], ax=ax[0], title='Batch size = 16')
results_32.plot(x='epoch', y=['loss', 'val_loss'], ax=ax[1], title='Batch size = 32')
results_128.plot(x='epoch', y=['loss', 'val_loss'], ax=ax[2], title='Batch size = 128')
# Out:
# <AxesSubplot:title={'center':'Batch size = 128'}, xlabel='epoch'>

# %% [markdown]
# # Shallow vs Deep Neural Networks
#
# Now, let us investigate the effect of depth on the performance of neural networks. We will return to the full training set since we want to compare true accuracies.

# %% [markdown]
# ## Shallow Baseline
#
# First, let us get a baseline with our shallow_nn. We will train for 20 Epochs, using some sensible parameters we have found before.

# %%
results_shallow = evaluator.evaluate(
    optimizer=SGD(0.01),
    batch_size=64,
    epochs=30,
    verbose=2,  # let us output some training details so that we have something to watch
    x=x_train,  # We use the full set again
    y=y_train,
)
# Out:
# Epoch 1/30
# 938/938 - 1s - loss: 0.9995 - accuracy: 0.6879 - val_loss: 0.6982 - val_accuracy: 0.7610 - 1s/epoch - 1ms/step
# Epoch 2/30
# 938/938 - 1s - loss: 0.6194 - accuracy: 0.7931 - val_loss: 0.5925 - val_accuracy: 0.7987 - 952ms/epoch - 1ms/step
# Epoch 3/30
# 938/938 - 1s - loss: 0.5486 - accuracy: 0.8137 - val_loss: 0.5497 - val_accuracy: 0.8098 - 777ms/epoch - 828us/step
# Epoch 4/30
# 938/938 - 1s - loss: 0.5123 - accuracy: 0.8244 - val_loss: 0.5245 - val_accuracy: 0.8183 - 771ms/epoch - 822us/step
# Epoch 5/30
# 938/938 - 1s - loss: 0.4889 - accuracy: 0.8313 - val_loss: 0.5120 - val_accuracy: 0.8227 - 780ms/epoch - 832us/step
# Epoch 6/30
# 938/938 - 1s - loss: 0.4725 - accuracy: 0.8367 - val_loss: 0.4981 - val_accuracy: 0.8274 - 806ms/epoch - 860us/step
# Epoch 7/30
# 938/938 - 1s - loss: 0.4602 - accuracy: 0.8412 - val_loss: 0.4843 - val_accuracy: 0.8326 - 871ms/epoch - 929us/step
# Epoch 8/30
# 938/938 - 1s - loss: 0.4495 - accuracy: 0.8429 - val_loss: 0.4731 - val_accuracy: 0.8374 - 790ms/epoch - 842us/step
# Epoch 9/30
# 938/938 - 1s - loss: 0.4411 - accuracy: 0.8462 - val_loss: 0.4695 - val_accuracy: 0.8360 - 773ms/epoch - 824us/step
# Epoch 10/30
# 938/938 - 1s - loss: 0.4333 - accuracy: 0.8490 - val_loss: 0.4637 - val_accuracy: 0.8362 - 776ms/epoch - 828us/step
# Epoch 11/30
# 938/938 - 1s - loss: 0.4264 - accuracy: 0.8516 - val_loss: 0.4609 - val_accuracy: 0.8391 - 774ms/epoch - 826us/step
# Epoch 12/30
# 938/938 - 1s - loss: 0.4213 - accuracy: 0.8544 - val_loss: 0.4527 - val_accuracy: 0.8411 - 854ms/epoch - 910us/step
# Epoch 13/30
# 938/938 - 1s - loss: 0.4162 - accuracy: 0.8562 - val_loss: 0.4572 - val_accuracy: 0.8397 - 884ms/epoch - 942us/step
# Epoch 14/30
# 938/938 - 1s - loss: 0.4110 - accuracy: 0.8572 - val_loss: 0.4463 - val_accuracy: 0.8423 - 848ms/epoch - 904us/step
# Epoch 15/30
# 938/938 - 1s - loss: 0.4066 - accuracy: 0.8590 - val_loss: 0.4517 - val_accuracy: 0.8417 - 817ms/epoch - 871us/step
# Epoch 16/30
# 938/938 - 1s - loss: 0.4035 - accuracy: 0.8594 - val_loss: 0.4384 - val_accuracy: 0.8464 - 861ms/epoch - 918us/step
# Epoch 17/30
# 938/938 - 1s - loss: 0.3988 - accuracy: 0.8619 - val_loss: 0.4442 - val_accuracy: 0.8418 - 792ms/epoch - 844us/step
# Epoch 18/30
# 938/938 - 1s - loss: 0.3957 - accuracy: 0.8629 - val_loss: 0.4408 - val_accuracy: 0.8456 - 813ms/epoch - 867us/step
# Epoch 19/30
# 938/938 - 1s - loss: 0.3924 - accuracy: 0.8636 - val_loss: 0.4352 - val_accuracy: 0.8466 - 836ms/epoch - 891us/step
# Epoch 20/30
# 938/938 - 1s - loss: 0.3889 - accuracy: 0.8656 - val_loss: 0.4274 - val_accuracy: 0.8495 - 821ms/epoch - 876us/step
# Epoch 21/30
# 938/938 - 1s - loss: 0.3858 - accuracy: 0.8655 - val_loss: 0.4296 - val_accuracy: 0.8466 - 775ms/epoch - 826us/step
# Epoch 22/30
# 938/938 - 1s - loss: 0.3831 - accuracy: 0.8673 - val_loss: 0.4211 - val_accuracy: 0.8520 - 845ms/epoch - 900us/step
# Epoch 23/30
# 938/938 - 1s - loss: 0.3803 - accuracy: 0.8671 - val_loss: 0.4229 - val_accuracy: 0.8518 - 806ms/epoch - 859us/step
# Epoch 24/30
# 938/938 - 1s - loss: 0.3772 - accuracy: 0.8691 - val_loss: 0.4191 - val_accuracy: 0.8521 - 875ms/epoch - 933us/step
# Epoch 25/30
# 938/938 - 1s - loss: 0.3749 - accuracy: 0.8693 - val_loss: 0.4172 - val_accuracy: 0.8539 - 1s/epoch - 1ms/step
# Epoch 26/30
# 938/938 - 1s - loss: 0.3732 - accuracy: 0.8702 - val_loss: 0.4250 - val_accuracy: 0.8493 - 1s/epoch - 1ms/step
# Epoch 27/30
# 938/938 - 1s - loss: 0.3706 - accuracy: 0.8710 - val_loss: 0.4194 - val_accuracy: 0.8509 - 1s/epoch - 1ms/step
# Epoch 28/30
# 938/938 - 1s - loss: 0.3684 - accuracy: 0.8712 - val_loss: 0.4108 - val_accuracy: 0.8562 - 907ms/epoch - 967us/step
# Epoch 29/30
# 938/938 - 1s - loss: 0.3668 - accuracy: 0.8727 - val_loss: 0.4128 - val_accuracy: 0.8554 - 848ms/epoch - 904us/step
# Epoch 30/30
# 938/938 - 1s - loss: 0.3640 - accuracy: 0.8729 - val_loss: 0.4179 - val_accuracy: 0.8515 - 824ms/epoch - 878us/step

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 4))
results_shallow.plot(x='epoch', y=['loss', 'val_loss'], ax=ax[0], title='Loss')
results_shallow.plot(x='epoch', y=['accuracy', 'val_accuracy'], ax=ax[1], title='Accuracy')
# Out:
# <AxesSubplot:title={'center':'Accuracy'}, xlabel='epoch'>

# %% [markdown]
# Let's see what we have gotten wrong...

# %%
y_hat_test = shallow_nn.predict(x_test)
correct = y_hat_test.argmax(1) == y_test.argmax(1)
labels = [
    f'Correct: {c} \n True: {label_dict[y]} | Pred: {label_dict[yh]}'
    for c, y, yh in zip(correct, y_test.argmax(1), y_hat_test.argmax(1))
]

# %%
plot_images(x_test, labels=labels)

# %% [markdown]
# ## Going Deeper
#
# Let us now define a deeper network. Since we are not doing any repeated evaluations we just compile and train it as usual...

# %%
def build_deep_nn(layer_sizes):
    x = Input(shape=(28, 28, 1))
    h = Flatten()(x)
    for l in layer_sizes:
        h = Dense(units=l, activation='relu')(h)
    y = Dense(units=10, activation='softmax')(h)
    return Model(inputs=x, outputs=y)

# %%
deep_nn = build_deep_nn(layer_sizes=[512, 256, 128])

# %%
deep_nn.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_2 (Dense)             (None, 512)               401920
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 567,434
# Trainable params: 567,434
# Non-trainable params: 0
# _________________________________________________________________

# %%
deep_nn.compile(
    loss=categorical_crossentropy,
    optimizer=SGD(0.01),
    metrics=['accuracy'],
)

# %%
history = deep_nn.fit(
    x=x_train,
    y=y_train,
    batch_size=128,
    epochs=30,
    validation_data=(x_test, y_test),
    verbose=2,
)
# Out:
# Epoch 1/30
# 469/469 - 2s - loss: 1.0060 - accuracy: 0.6897 - val_loss: 0.6782 - val_accuracy: 0.7703 - 2s/epoch - 4ms/step
# Epoch 2/30
# 469/469 - 1s - loss: 0.5878 - accuracy: 0.8037 - val_loss: 0.5531 - val_accuracy: 0.8088 - 1s/epoch - 3ms/step
# Epoch 3/30
# 469/469 - 1s - loss: 0.5162 - accuracy: 0.8226 - val_loss: 0.5534 - val_accuracy: 0.7940 - 1s/epoch - 3ms/step
# Epoch 4/30
# 469/469 - 1s - loss: 0.4819 - accuracy: 0.8319 - val_loss: 0.4967 - val_accuracy: 0.8250 - 1s/epoch - 3ms/step
# Epoch 5/30
# 469/469 - 1s - loss: 0.4611 - accuracy: 0.8392 - val_loss: 0.4973 - val_accuracy: 0.8212 - 1s/epoch - 3ms/step
# Epoch 6/30
# 469/469 - 2s - loss: 0.4441 - accuracy: 0.8439 - val_loss: 0.4728 - val_accuracy: 0.8331 - 2s/epoch - 3ms/step
# Epoch 7/30
# 469/469 - 2s - loss: 0.4295 - accuracy: 0.8495 - val_loss: 0.4530 - val_accuracy: 0.8390 - 2s/epoch - 3ms/step
# Epoch 8/30
# 469/469 - 2s - loss: 0.4182 - accuracy: 0.8532 - val_loss: 0.4521 - val_accuracy: 0.8393 - 2s/epoch - 3ms/step
# Epoch 9/30
# 469/469 - 2s - loss: 0.4096 - accuracy: 0.8565 - val_loss: 0.4302 - val_accuracy: 0.8446 - 2s/epoch - 3ms/step
# Epoch 10/30
# 469/469 - 2s - loss: 0.3978 - accuracy: 0.8614 - val_loss: 0.4287 - val_accuracy: 0.8447 - 2s/epoch - 3ms/step
# Epoch 11/30
# 469/469 - 2s - loss: 0.3888 - accuracy: 0.8635 - val_loss: 0.4476 - val_accuracy: 0.8395 - 2s/epoch - 3ms/step
# Epoch 12/30
# 469/469 - 1s - loss: 0.3813 - accuracy: 0.8662 - val_loss: 0.4331 - val_accuracy: 0.8429 - 1s/epoch - 3ms/step
# Epoch 13/30
# 469/469 - 1s - loss: 0.3749 - accuracy: 0.8684 - val_loss: 0.4163 - val_accuracy: 0.8499 - 1s/epoch - 3ms/step
# Epoch 14/30
# 469/469 - 2s - loss: 0.3691 - accuracy: 0.8705 - val_loss: 0.4025 - val_accuracy: 0.8562 - 2s/epoch - 4ms/step
# Epoch 15/30
# 469/469 - 2s - loss: 0.3622 - accuracy: 0.8723 - val_loss: 0.3992 - val_accuracy: 0.8576 - 2s/epoch - 3ms/step
# Epoch 16/30
# 469/469 - 2s - loss: 0.3563 - accuracy: 0.8742 - val_loss: 0.4142 - val_accuracy: 0.8548 - 2s/epoch - 3ms/step
# Epoch 17/30
# 469/469 - 1s - loss: 0.3507 - accuracy: 0.8760 - val_loss: 0.3943 - val_accuracy: 0.8591 - 1s/epoch - 3ms/step
# Epoch 18/30
# 469/469 - 1s - loss: 0.3462 - accuracy: 0.8774 - val_loss: 0.3878 - val_accuracy: 0.8576 - 1s/epoch - 3ms/step
# Epoch 19/30
# 469/469 - 2s - loss: 0.3403 - accuracy: 0.8793 - val_loss: 0.3863 - val_accuracy: 0.8620 - 2s/epoch - 4ms/step
# Epoch 20/30
# 469/469 - 2s - loss: 0.3358 - accuracy: 0.8807 - val_loss: 0.3799 - val_accuracy: 0.8626 - 2s/epoch - 5ms/step
# Epoch 21/30
# 469/469 - 3s - loss: 0.3306 - accuracy: 0.8828 - val_loss: 0.3836 - val_accuracy: 0.8623 - 3s/epoch - 5ms/step
# Epoch 22/30
# 469/469 - 2s - loss: 0.3265 - accuracy: 0.8834 - val_loss: 0.4003 - val_accuracy: 0.8584 - 2s/epoch - 4ms/step
# Epoch 23/30
# 469/469 - 2s - loss: 0.3217 - accuracy: 0.8863 - val_loss: 0.3781 - val_accuracy: 0.8641 - 2s/epoch - 4ms/step
# Epoch 24/30
# 469/469 - 2s - loss: 0.3192 - accuracy: 0.8859 - val_loss: 0.3714 - val_accuracy: 0.8669 - 2s/epoch - 4ms/step
# Epoch 25/30
# 469/469 - 2s - loss: 0.3146 - accuracy: 0.8873 - val_loss: 0.3774 - val_accuracy: 0.8645 - 2s/epoch - 3ms/step
# Epoch 26/30
# 469/469 - 2s - loss: 0.3109 - accuracy: 0.8891 - val_loss: 0.3767 - val_accuracy: 0.8628 - 2s/epoch - 3ms/step
# Epoch 27/30
# 469/469 - 2s - loss: 0.3081 - accuracy: 0.8889 - val_loss: 0.3581 - val_accuracy: 0.8701 - 2s/epoch - 3ms/step
# Epoch 28/30
# 469/469 - 2s - loss: 0.3054 - accuracy: 0.8902 - val_loss: 0.3623 - val_accuracy: 0.8701 - 2s/epoch - 3ms/step
# Epoch 29/30
# 469/469 - 2s - loss: 0.3013 - accuracy: 0.8921 - val_loss: 0.3544 - val_accuracy: 0.8720 - 2s/epoch - 4ms/step
# Epoch 30/30
# 469/469 - 2s - loss: 0.2968 - accuracy: 0.8931 - val_loss: 0.3567 - val_accuracy: 0.8736 - 2s/epoch - 3ms/step

# %%
results_deep = pd.DataFrame(history.history)
results_deep['epoch'] = history.epoch

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 4), sharey=True)
results_shallow.plot(x='epoch', y=['accuracy', 'val_accuracy'], ax=ax[0], title='Shallow')
results_deep.plot(x='epoch', y=['accuracy', 'val_accuracy'], ax=ax[1], title='Deep')
# Out:
# <AxesSubplot:title={'center':'Deep'}, xlabel='epoch'>

# %% [markdown]
# **Exercise.** Try to go deeper and wider, does that help?

# %% [markdown]
# # The Effect of Permutation on Fully Connected Networks
#
# We have discussed in class that permutation does not affect fully connected networks. Let us confirm this here.

# %%
def permute_pixels(*images):
    img_size = images[0].shape[1:-1]
    idx = np.random.permutation(img_size[0])
    idy = np.random.permutation(img_size[1])
    images_permuted = []
    for img in images:
        img_perm = img[:, idx, :, :]
        img_perm = img_perm[:, :, idy, :]
        images_permuted.append(img_perm)
    return images_permuted

# %%
x_train_perm, x_test_perm = permute_pixels(x_train, x_test)

# %%
plot_images(x_train_perm, labels_train)

# %% [markdown]
# Clearly, humans have no way of telling these apart. Let us see how our shallow NN works on this dataset.

# %%
results_perm = evaluator.evaluate(
    optimizer=SGD(0.01),
    batch_size=64,
    epochs=30,
    verbose=2,
    x=x_train_perm,
    y=y_train,
    validation_data=(x_test_perm, y_test),
)
# Out:
# Epoch 1/30
# 938/938 - 1s - loss: 0.9870 - accuracy: 0.6910 - val_loss: 0.7006 - val_accuracy: 0.7623 - 1s/epoch - 2ms/step
# Epoch 2/30
# 938/938 - 1s - loss: 0.6176 - accuracy: 0.7954 - val_loss: 0.6007 - val_accuracy: 0.7956 - 781ms/epoch - 833us/step
# Epoch 3/30
# 938/938 - 1s - loss: 0.5465 - accuracy: 0.8163 - val_loss: 0.5474 - val_accuracy: 0.8136 - 780ms/epoch - 832us/step
# Epoch 4/30
# 938/938 - 1s - loss: 0.5100 - accuracy: 0.8271 - val_loss: 0.5245 - val_accuracy: 0.8197 - 837ms/epoch - 892us/step
# Epoch 5/30
# 938/938 - 1s - loss: 0.4867 - accuracy: 0.8331 - val_loss: 0.5078 - val_accuracy: 0.8234 - 778ms/epoch - 830us/step
# Epoch 6/30
# 938/938 - 1s - loss: 0.4712 - accuracy: 0.8375 - val_loss: 0.4971 - val_accuracy: 0.8247 - 787ms/epoch - 839us/step
# Epoch 7/30
# 938/938 - 1s - loss: 0.4576 - accuracy: 0.8422 - val_loss: 0.4816 - val_accuracy: 0.8298 - 802ms/epoch - 855us/step
# Epoch 8/30
# 938/938 - 1s - loss: 0.4478 - accuracy: 0.8456 - val_loss: 0.4725 - val_accuracy: 0.8355 - 776ms/epoch - 827us/step
# Epoch 9/30
# 938/938 - 1s - loss: 0.4392 - accuracy: 0.8490 - val_loss: 0.4648 - val_accuracy: 0.8346 - 782ms/epoch - 834us/step
# Epoch 10/30
# 938/938 - 1s - loss: 0.4319 - accuracy: 0.8511 - val_loss: 0.4636 - val_accuracy: 0.8367 - 776ms/epoch - 828us/step
# Epoch 11/30
# 938/938 - 1s - loss: 0.4249 - accuracy: 0.8527 - val_loss: 0.4624 - val_accuracy: 0.8368 - 795ms/epoch - 847us/step
# Epoch 12/30
# 938/938 - 1s - loss: 0.4193 - accuracy: 0.8553 - val_loss: 0.4641 - val_accuracy: 0.8351 - 782ms/epoch - 834us/step
# Epoch 13/30
# 938/938 - 1s - loss: 0.4144 - accuracy: 0.8575 - val_loss: 0.4533 - val_accuracy: 0.8376 - 777ms/epoch - 828us/step
# Epoch 14/30
# 938/938 - 1s - loss: 0.4098 - accuracy: 0.8583 - val_loss: 0.4420 - val_accuracy: 0.8430 - 772ms/epoch - 823us/step
# Epoch 15/30
# 938/938 - 1s - loss: 0.4057 - accuracy: 0.8603 - val_loss: 0.4483 - val_accuracy: 0.8414 - 924ms/epoch - 985us/step
# Epoch 16/30
# 938/938 - 1s - loss: 0.4024 - accuracy: 0.8601 - val_loss: 0.4466 - val_accuracy: 0.8409 - 871ms/epoch - 928us/step
# Epoch 17/30
# 938/938 - 1s - loss: 0.3983 - accuracy: 0.8626 - val_loss: 0.4362 - val_accuracy: 0.8441 - 817ms/epoch - 871us/step
# Epoch 18/30
# 938/938 - 1s - loss: 0.3951 - accuracy: 0.8640 - val_loss: 0.4355 - val_accuracy: 0.8453 - 781ms/epoch - 832us/step
# Epoch 19/30
# 938/938 - 1s - loss: 0.3919 - accuracy: 0.8647 - val_loss: 0.4292 - val_accuracy: 0.8488 - 806ms/epoch - 859us/step
# Epoch 20/30
# 938/938 - 1s - loss: 0.3883 - accuracy: 0.8655 - val_loss: 0.4471 - val_accuracy: 0.8416 - 775ms/epoch - 826us/step
# Epoch 21/30
# 938/938 - 1s - loss: 0.3854 - accuracy: 0.8665 - val_loss: 0.4215 - val_accuracy: 0.8487 - 770ms/epoch - 820us/step
# Epoch 22/30
# 938/938 - 1s - loss: 0.3828 - accuracy: 0.8668 - val_loss: 0.4248 - val_accuracy: 0.8471 - 809ms/epoch - 862us/step
# Epoch 23/30
# 938/938 - 1s - loss: 0.3800 - accuracy: 0.8685 - val_loss: 0.4307 - val_accuracy: 0.8463 - 836ms/epoch - 891us/step
# Epoch 24/30
# 938/938 - 1s - loss: 0.3776 - accuracy: 0.8685 - val_loss: 0.4288 - val_accuracy: 0.8447 - 785ms/epoch - 837us/step
# Epoch 25/30
# 938/938 - 1s - loss: 0.3750 - accuracy: 0.8707 - val_loss: 0.4146 - val_accuracy: 0.8532 - 844ms/epoch - 899us/step
# Epoch 26/30
# 938/938 - 1s - loss: 0.3732 - accuracy: 0.8705 - val_loss: 0.4128 - val_accuracy: 0.8518 - 842ms/epoch - 898us/step
# Epoch 27/30
# 938/938 - 1s - loss: 0.3707 - accuracy: 0.8714 - val_loss: 0.4117 - val_accuracy: 0.8521 - 788ms/epoch - 840us/step
# Epoch 28/30
# 938/938 - 1s - loss: 0.3679 - accuracy: 0.8727 - val_loss: 0.4222 - val_accuracy: 0.8502 - 862ms/epoch - 918us/step
# Epoch 29/30
# 938/938 - 1s - loss: 0.3658 - accuracy: 0.8726 - val_loss: 0.4120 - val_accuracy: 0.8513 - 826ms/epoch - 881us/step
# Epoch 30/30
# 938/938 - 1s - loss: 0.3641 - accuracy: 0.8731 - val_loss: 0.4075 - val_accuracy: 0.8531 - 858ms/epoch - 914us/step

# %% [markdown]
# Let us now compare the results with the shallow NN baseline with un-permuted data.

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 4), sharey=True)
results_shallow.plot(x='epoch', y=['accuracy', 'val_accuracy'], ax=ax[0], title='Original')
results_perm.plot(x='epoch', y=['accuracy', 'val_accuracy'], ax=ax[1], title='Permuted')
# Out:
# <AxesSubplot:title={'center':'Permuted'}, xlabel='epoch'>

# %% [markdown]
# They are almost indistinguisable! This highlights that the fully connected NN, while being a sufficiently accurate model, is not at all doing what humans are doing when we recognize these images!

# %% [markdown]
# # Convolutional Neural Networks on Fashion MNIST
#
# Let us now test the performance of convolutional neural networks (CNNs) on the performance on Fashion MNIST.

# %%
from tensorflow.keras.layers import Conv2D, MaxPool2D

# %%
x = Input(shape=(28, 28, 1))

# %%
# Convolution + pool 1
h1 = Conv2D(filters=6, kernel_size=3, activation='relu', padding='same')(x)

# %%
h1 = MaxPool2D(strides=2)(h1)

# %%
# Convolution + pool 2
h2 = Conv2D(filters=16, kernel_size=3, activation='relu', padding='same')(h1)
h2 = MaxPool2D(strides=2)(h2)

# %%
h2
# Out:
# <KerasTensor: shape=(None, 7, 7, 16) dtype=float32 (created by layer 'max_pooling2d_1')>

# %%
# Fully connected
h2_flattened = Flatten()(h2)

# %%
h3 = Dense(units=120, activation='relu')(h2_flattened)
h4 = Dense(units=84, activation='relu')(h3)
h5 = Dense(units=10, activation='softmax')(h4)

cnn = Model(inputs=x, outputs=h5)

# %%
cnn.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 6)         60
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 6)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 16)        880
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 16)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_6 (Dense)             (None, 120)               94200
#
#  dense_7 (Dense)             (None, 84)                10164
#
#  dense_8 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 106,154
# Trainable params: 106,154
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Let's train and evaluate the CNN using our `ParamEvaluator` class as before. (Uncomment to run)

# %%
evaluator_cnn = ParamEvaluator(
    model=cnn,
    compile_default={
        'loss': categorical_crossentropy,
        'optimizer': SGD(learning_rate=0.1),
        'metrics': ['accuracy'],
    },
    fit_default={
        'x': x_train,
        'y': y_train,
        'batch_size': 128,
        'epochs': 30,
        'validation_data': (x_test, y_test),
        'verbose': 2,
    }
)

results_cnn = evaluator_cnn.evaluate()
cnn.save('cnn.h5')
# Out:
# Epoch 1/30
# 469/469 - 9s - loss: 0.7746 - accuracy: 0.7015 - val_loss: 0.5205 - val_accuracy: 0.8115 - 9s/epoch - 18ms/step
# Epoch 2/30
# 469/469 - 9s - loss: 0.4483 - accuracy: 0.8333 - val_loss: 0.4466 - val_accuracy: 0.8348 - 9s/epoch - 19ms/step
# Epoch 3/30
# 469/469 - 9s - loss: 0.3768 - accuracy: 0.8613 - val_loss: 0.3991 - val_accuracy: 0.8576 - 9s/epoch - 20ms/step
# Epoch 4/30
# 469/469 - 10s - loss: 0.3378 - accuracy: 0.8759 - val_loss: 0.3506 - val_accuracy: 0.8746 - 10s/epoch - 21ms/step
# Epoch 5/30
# 469/469 - 9s - loss: 0.3137 - accuracy: 0.8841 - val_loss: 0.3357 - val_accuracy: 0.8814 - 9s/epoch - 19ms/step
# Epoch 6/30
# 469/469 - 9s - loss: 0.2974 - accuracy: 0.8884 - val_loss: 0.3517 - val_accuracy: 0.8700 - 9s/epoch - 19ms/step
# Epoch 7/30
# 469/469 - 9s - loss: 0.2796 - accuracy: 0.8957 - val_loss: 0.3062 - val_accuracy: 0.8855 - 9s/epoch - 20ms/step
# Epoch 8/30
# 469/469 - 9s - loss: 0.2675 - accuracy: 0.9012 - val_loss: 0.3022 - val_accuracy: 0.8878 - 9s/epoch - 19ms/step
# Epoch 9/30
# 469/469 - 9s - loss: 0.2552 - accuracy: 0.9042 - val_loss: 0.3146 - val_accuracy: 0.8838 - 9s/epoch - 19ms/step
# Epoch 10/30
# 469/469 - 9s - loss: 0.2451 - accuracy: 0.9083 - val_loss: 0.2908 - val_accuracy: 0.8954 - 9s/epoch - 19ms/step
# Epoch 11/30
# 469/469 - 10s - loss: 0.2382 - accuracy: 0.9103 - val_loss: 0.2860 - val_accuracy: 0.8947 - 10s/epoch - 21ms/step
# Epoch 12/30
# 469/469 - 10s - loss: 0.2303 - accuracy: 0.9133 - val_loss: 0.2881 - val_accuracy: 0.8963 - 10s/epoch - 21ms/step
# Epoch 13/30
# 469/469 - 10s - loss: 0.2233 - accuracy: 0.9169 - val_loss: 0.2975 - val_accuracy: 0.8955 - 10s/epoch - 22ms/step
# Epoch 14/30
# 469/469 - 9s - loss: 0.2138 - accuracy: 0.9204 - val_loss: 0.2863 - val_accuracy: 0.8976 - 9s/epoch - 20ms/step
# Epoch 15/30
# 469/469 - 9s - loss: 0.2068 - accuracy: 0.9218 - val_loss: 0.2759 - val_accuracy: 0.9036 - 9s/epoch - 20ms/step
# Epoch 16/30
# 469/469 - 10s - loss: 0.2013 - accuracy: 0.9238 - val_loss: 0.2913 - val_accuracy: 0.8969 - 10s/epoch - 22ms/step
# Epoch 17/30
# 469/469 - 10s - loss: 0.1955 - accuracy: 0.9253 - val_loss: 0.2896 - val_accuracy: 0.8982 - 10s/epoch - 22ms/step
# Epoch 18/30
# 469/469 - 10s - loss: 0.1887 - accuracy: 0.9284 - val_loss: 0.2883 - val_accuracy: 0.9019 - 10s/epoch - 21ms/step
# Epoch 19/30
# 469/469 - 9s - loss: 0.1837 - accuracy: 0.9299 - val_loss: 0.2850 - val_accuracy: 0.9006 - 9s/epoch - 20ms/step
# Epoch 20/30
# 469/469 - 10s - loss: 0.1791 - accuracy: 0.9316 - val_loss: 0.2994 - val_accuracy: 0.8908 - 10s/epoch - 21ms/step
# Epoch 21/30
# 469/469 - 11s - loss: 0.1713 - accuracy: 0.9354 - val_loss: 0.2850 - val_accuracy: 0.9057 - 11s/epoch - 23ms/step
# Epoch 22/30
# 469/469 - 10s - loss: 0.1657 - accuracy: 0.9370 - val_loss: 0.2793 - val_accuracy: 0.9060 - 10s/epoch - 21ms/step
# Epoch 23/30
# 469/469 - 10s - loss: 0.1611 - accuracy: 0.9399 - val_loss: 0.2950 - val_accuracy: 0.9019 - 10s/epoch - 21ms/step
# Epoch 24/30
# 469/469 - 10s - loss: 0.1582 - accuracy: 0.9403 - val_loss: 0.2825 - val_accuracy: 0.9040 - 10s/epoch - 22ms/step
# Epoch 25/30
# 469/469 - 10s - loss: 0.1515 - accuracy: 0.9428 - val_loss: 0.3308 - val_accuracy: 0.8944 - 10s/epoch - 22ms/step
# Epoch 26/30
# 469/469 - 10s - loss: 0.1479 - accuracy: 0.9446 - val_loss: 0.2851 - val_accuracy: 0.9094 - 10s/epoch - 22ms/step
# Epoch 27/30
# 469/469 - 10s - loss: 0.1435 - accuracy: 0.9449 - val_loss: 0.3161 - val_accuracy: 0.8955 - 10s/epoch - 21ms/step
# Epoch 28/30
# 469/469 - 9s - loss: 0.1364 - accuracy: 0.9484 - val_loss: 0.3138 - val_accuracy: 0.9005 - 9s/epoch - 20ms/step
# Epoch 29/30
# 469/469 - 10s - loss: 0.1344 - accuracy: 0.9479 - val_loss: 0.2941 - val_accuracy: 0.9046 - 10s/epoch - 21ms/step
# Epoch 30/30
# 469/469 - 10s - loss: 0.1303 - accuracy: 0.9505 - val_loss: 0.2950 - val_accuracy: 0.9029 - 10s/epoch - 21ms/step

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 4), sharey=True)
results_deep.plot(x='epoch', y=['accuracy', 'val_accuracy'], ax=ax[0], title='Deep FCNN')
results_cnn.plot(x='epoch', y=['accuracy', 'val_accuracy'], ax=ax[1], title='CNN')
# Out:
# <AxesSubplot:title={'center':'CNN'}, xlabel='epoch'>

# %% [markdown]
# We can skip the training before if we have a saved model, which we can just load

# %%
from sklearn.metrics import accuracy_score

# %%
cnn = tf.keras.models.load_model('cnn.h5')

# %%
y_hat_train_cnn = cnn.predict(x_train)
y_hat_test_cnn = cnn.predict(x_test)
y_hat_train_fcnn = deep_nn.predict(x_train)
y_hat_test_fcnn = deep_nn.predict(x_test)

print(f'FCNN train accuracy: {accuracy_score(y_train.argmax(1), y_hat_train_fcnn.argmax(1))}')
print(f'FCNN test accuracy: {accuracy_score(y_test.argmax(1), y_hat_test_fcnn.argmax(1))}')

print(f'CNN train accuracy: {accuracy_score(y_train.argmax(1), y_hat_train_cnn.argmax(1))}')
print(f'CNN test accuracy: {accuracy_score(y_test.argmax(1), y_hat_test_cnn.argmax(1))}')
# Out:
# FCNN train accuracy: 0.8974166666666666
# FCNN test accuracy: 0.8736
# CNN train accuracy: 0.9576666666666667
# CNN test accuracy: 0.9029

# %% [markdown]
# There are many things you can do to improve the above, including by not limited to
#   * Tweak network sizes/depth and overall architecture
#   * Use other optimizers (e.g. try Adam!)
#   * Data augmentation (see [keras functionalities](https://keras.io/preprocessing/image/))

# %% [markdown]
# ## Exploring the Trained Network

# %% [markdown]
# Let us first look at the features that are extracted in our convolution layers. We use a trick by defining a new `keras` model that has these feature maps as outputs, so we can easily call the `predict` method to get the results.

# %%
cnn_feature_maps = Model(inputs=x, outputs=[h1, h2])

# %%
h1_val, h2_val = cnn_feature_maps.predict(x_test)

# %%
plot_images(h1_val, labels=labels_test)

# %%
plot_images(h2_val, labels=labels_test)
